# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/cleaned_tickets.csv")

# %%
high_priority_keywords = [
    'payment failed',
    'server down',
    'account hacked',
    'unable login',
    'system crash'
]

# %%
medium_priority_keywords = [
    'slow',
    'delay',
    'bug',
    'issue',
    'not working'
]

# %%
def assign_priority(text):
    
    text = str(text).lower()
    
    for word in high_priority_keywords:
        if word in text:
            return "High"
    
    for word in medium_priority_keywords:
        if word in text:
            return "Medium"
    
    return "Low"

# %%
df['priority'] = df['cleaned_text'].apply(assign_priority)

# %%
df[['cleaned_text', 'priority']].head()
# Out:
#                                         cleaned_text priority
# 0  im issue productpurchased please assist billin...   Medium
# 1  im issue productpurchased please assist need c...   Medium
# 2  im facing problem productpurchased productpurc...      Low
# 3  im issue productpurchased please assist proble...   Medium
# 4  im issue productpurchased please assist note s...   Medium

# %%
df['priority'].value_counts()
# Out:
# priority
# Medium    7783
# Low        684
# High         2
# Name: count, dtype: int64

# %%
df.to_csv("../outputs/predictions.csv", index=False)
